# %%
#code snippet 1
#installing pycaret package for ML model prediction
# !pip install git+https://github.com/pycaret/pycaret.git

# %%
#code snippet 2
#inserting data from the url to initiate ML algorithm
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Imjuandiaz/churn-data/refs/heads/main/WA_Fn-UseC_-Telco-Customer-Churn.csv")

df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %%
#Code snippet 3
#displaying columns
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#code snippet 4
#setting up the classification pycaret ML model
from pycaret.classification import *

# %%
# Code snippet 5
# Setting the target variable
y = 'Churn'

# %%
# Code snippet 6
# Setting the ignored variables(noise variables, redundant variables,  variables that are missing more than 20% data etc)
ignored_cols = ['customerID','gender','MonthlyCharges', 'TotalCharges', 'PhoneService', 'MultipleLines']

# %%
# Code snippet 7
# Setting the numerical variables
num_cols = ['SeniorCitizen', 'tenure']

# %%
# Code snippet 8
# Setting the categorical variables
cat_cols = [ 'Partner', 'Dependents',
        'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod' ]

# %%
# Code snippet 9
# Setting up/configuring the pycaret setup for Classification ML modeling
classification_setup = setup(df,
                        target = y,
                        ignore_features = ignored_cols,
                        categorical_features = cat_cols,
                        numeric_features = num_cols, train_size = 0.7)
# Out:
# <style type="text/css">
# #T_3e74c_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3e74c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e74c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3e74c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e74c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3e74c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3e74c_row0_col1" class="data row0 col1" >2741</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3e74c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3e74c_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3e74c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3e74c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3e74c_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_3e74c_row3_col1" class="data row3 col1" >No: 0, Yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3e74c_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_3e74c_row4_col1" class="data row4 col1" >(7043, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3e74c_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_3e74c_row5_col1" class="data row5 col1" >(7043, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3e74c_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_3e74c_row6_col1" class="data row6 col1" >(4930, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3e74c_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_3e74c_row7_col1" class="data row7 col1" >(2113, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3e74c_row8_col0" class="data row8 col0" >Ignore features</td>
#       <td id="T_3e74c_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3e74c_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_3e74c_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3e74c_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_3e74c_row10_col1" class="data row10 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3e74c_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_3e74c_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3e74c_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_3e74c_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3e74c_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_3e74c_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3e74c_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_3e74c_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3e74c_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_3e74c_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3e74c_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_3e74c_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3e74c_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_3e74c_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3e74c_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_3e74c_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3e74c_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_3e74c_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3e74c_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_3e74c_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3e74c_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_3e74c_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_3e74c_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_3e74c_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3e74c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_3e74c_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_3e74c_row23_col1" class="data row23 col1" >3c17</td>
#     </tr>
#   </tbody>
# </table>

# %%
#code snippet 10
# Running pycaret to invoke ML algorithms
compare_models()
# Out:
# <style type="text/css">
# #T_ea070 th {
#   text-align: left;
# }
# #T_ea070_row0_col0, #T_ea070_row0_col4, #T_ea070_row0_col5, #T_ea070_row0_col6, #T_ea070_row0_col7, #T_ea070_row1_col0, #T_ea070_row1_col1, #T_ea070_row1_col2, #T_ea070_row1_col3, #T_ea070_row1_col4, #T_ea070_row1_col6, #T_ea070_row1_col7, #T_ea070_row2_col0, #T_ea070_row2_col1, #T_ea070_row2_col2, #T_ea070_row2_col3, #T_ea070_row2_col4, #T_ea070_row2_col5, #T_ea070_row2_col6, #T_ea070_row2_col7, #T_ea070_row3_col0, #T_ea070_row3_col1, #T_ea070_row3_col2, #T_ea070_row3_col3, #T_ea070_row3_col4, #T_ea070_row4_col0, #T_ea070_row4_col1, #T_ea070_row4_col2, #T_ea070_row4_col3, #T_ea070_row4_col4, #T_ea070_row4_col5, #T_ea
row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_ea070_row0_col1" class="data row0 col1" >0.7994</td>
#       <td id="T_ea070_row0_col2" class="data row0 col2" >0.8427</td>
#       <td id="T_ea070_row0_col3" class="data row0 col3" >0.7994</td>
#       <td id="T_ea070_row0_col4" class="data row0 col4" >0.7890</td>
#       <td id="T_ea070_row0_col5" class="data row0 col5" >0.7903</td>
#       <td id="T_ea070_row0_col6" class="data row0 col6" >0.4446</td>
#       <td id="T_ea070_row0_col7" class="data row0 col7" >0.4516</td>
#       <td id="T_ea070_row0_col8" class="data row0 col8" >0.4630</td>
#     </tr>
#     <tr>
#       <th id="T_ea070_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_ea070_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_ea070_row1_col1" class="data row1 col1" >0.7992</td>
#       <td id="T_ea070_row1_col2" class="data row1 col2" >0.8368</td>
#       <td id="T_ea070_row1_col3" class="data row1 col3" >0.7992</td>
#       <td id="T_ea070_row1_col4" class="data row1 col4" >0.7900</td>
#       <td id="T_ea070_row1_col5" class="data row1 col5" >0.7920</td>
#       <td id="T_ea070_row1_col6" class="data row1 col6" >0.4520</td>
#       <td id="T_ea070_row1_col7" class="data row1 col7" >0.4566</td>
#       <td id="T_ea070_row1_col8" class="data row1 col8" >0.4500</td>
#     </tr>
#     <tr>
#       <th id="T_ea070_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_ea070_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_ea070_row2_col1" class="data row2 col1" >0.7978</td>
#       <td id="T_ea070_row2_col2" class="data row2 col2" >0.8415</td>
#       <td id="T_ea070_row2_col3" class="data row2 col3" >0.7978</td>
#       <td id="T_ea070_row2_col4" class="data row2 col4" >0.7879</td>
#       <td id="T_ea070_row2_col5" class="data row2 col5" >0.7897</td>
#       <td id="T_ea070_row2_col6" class="data row2 col6" >0.4448</td>
#       <td id="T_ea070_row2_col7" class="data row2 col7" >0.4503</td>
#       <td id="T_ea070_row2_col8" class="data row2 col8" >1.0170</td>
#     </tr>
#     <tr>
#       <th id="T_ea070_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_ea070_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_ea070_row3_col1" class="data row3 col1" >0.7978</td>
#       <td id="T_ea070_row3_col2" class="data row3 col2" >0.8332</td>
#       <td id="T_ea070_row3_col3" class="data row3 col3" >0.7978</td>
#       <td id="T_ea070_row3_col4" class="data row3 col4" >0.7897</td>
#       <td id="T_ea070_row3_col5" class="data row3 col5" >0.7920</td>
#       <td id="T_ea070_row3_col6" class="data row3 col6" >0.4542</td>
#       <td id="T_ea070_row3_col7" class="data row3 col7" >0.4574</td>
#       <td id="T_ea070_row3_col8" class="data row3 col8" >0.2550</td>
#     </tr>
#     <tr>
#       <th id="T_ea070_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_ea070_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_ea070_row4_col1" class="data row4 col1" >0.7976</td>
#       <td id="T_ea070_row4_col2" class="data row4 col2" >0.8332</td>
#       <td id="T_ea070_row4_col3" class="data row4 col3" >0.7976</td>
#       <td id="T_ea070_row4_col4" class="data row4 col4" >0.7862</td>
#       <td id="T_ea070_row4_col5" class="data row4 col5" >0.7872</td>
#       <td id="T_ea070_row4_col6" class="data row4 col6" >0.4350</td>
#       <td id="T_ea070_row4_col7" class="data row4 col7" >0.4432</td>
#       <td id="T_ea070_row4_col8" class="data row4 col8" >0.3230</td>
#     </tr>
#     <tr>
#       <th id="T_ea070_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_ea070_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ea070_row5_col1" class="data row5 col1" >0.7880</td>
#       <td id="T_ea070_row5_col2" class="data row5 col2" >0.8289</td>
#       <td id="T_ea070_row5_col3" class="data row5 col3" >0.7880</td>
#       <td id="T_ea070_row5_col4" class="data row5 col4" >0.7788</td>
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# AdaBoostClassifier(algorithm='SAMME.R', estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state
td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# Code snippet 12
# Predicting 'eBook Subscriber Flag' on a dataset
predictions = predict_model(best_model, df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_87376" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87376_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_87376_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_87376_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_87376_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_87376_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_87376_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_87376_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_87376_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87376_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87376_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_87376_row0_col1" class="data row0 col1" >0.8028</td>
#       <td id="T_87376_row0_col2" class="data row0 col2" >0.8522</td>
#       <td id="T_87376_row0_col3" class="data row0 col3" >0.8028</td>
#       <td id="T_87376_row0_col4" class="data row0 col4" >0.7919</td>
#       <td id="T_87376_row0_col5" class="data row0 col5" >0.7930</td>
#       <td id="T_87376_row0_col6" class="data row0 col6" >0.4503</td>
#       <td id="T_87376_row0_col7" class="data row0 col7" >0.4582</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Code snippet 13
# Exporting predictions to a csv file
predictions.to_csv('ada Churn predictions.csv')

# %%
#code snippet 14
#inserting data from the url to initiate prediction process
import pandas as pd

client_data = pd.read_csv("https://raw.githubusercontent.com/Imjuandiaz/churn-data/refs/heads/main/WA_Fn-UseC_-Telco-Customer-Churn.csv")

client_data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %%
# Code snippet 15
# Predicting 'eBook Subscriber Flag' for the client dataset
client_predictions = predict_model(best_model, client_data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8608a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8608a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8608a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8608a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8608a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8608a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8608a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8608a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8608a_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8608a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8608a_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_8608a_row0_col1" class="data row0 col1" >0.8028</td>
#       <td id="T_8608a_row0_col2" class="data row0 col2" >0.8522</td>
#       <td id="T_8608a_row0_col3" class="data row0 col3" >0.8028</td>
#       <td id="T_8608a_row0_col4" class="data row0 col4" >0.7919</td>
#       <td id="T_8608a_row0_col5" class="data row0 col5" >0.7930</td>
#       <td id="T_8608a_row0_col6" class="data row0 col6" >0.4503</td>
#       <td id="T_8608a_row0_col7" class="data row0 col7" >0.4582</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Code snippet 16
# Predicting 'eBook Subscriber Flag' for the client dataset
client_predictions = predict_model(best_model, client_data)


# Renaming label as Predicted 'eBook Subscriber Flag' and rounding it to 2 decimals
client_predictions = client_predictions.rename(columns = {'Label':'Churn prediction'}).round(2)


# Exporting 'eBook Subscriber Flag' predictions to a csv file
client_predictions.to_csv('1Final ADA Churn Prediction.csv')
# Out:
# <style type="text/css">
# </style>
# <table id="T_39439" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39439_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_39439_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_39439_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_39439_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_39439_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_39439_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_39439_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_39439_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39439_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_39439_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_39439_row0_col1" class="data row0 col1" >0.8028</td>
#       <td id="T_39439_row0_col2" class="data row0 col2" >0.8522</td>
#       <td id="T_39439_row0_col3" class="data row0 col3" >0.8028</td>
#       <td id="T_39439_row0_col4" class="data row0 col4" >0.7919</td>
#       <td id="T_39439_row0_col5" class="data row0 col5" >0.7930</td>
#       <td id="T_39439_row0_col6" class="data row0 col6" >0.4503</td>
#       <td id="T_39439_row0_col7" class="data row0 col7" >0.4582</td>
#     </tr>
#   </tbody>
# </table>

# %%
#code snippet 17
# getting the parameter for the Regression ML model
best_model_params = best_model.get_params()

# %%
#code snippet 18
#Print the Diccionary of Parameters
import pprint
pprint.pprint(best_model_params)
# Out:
# {'algorithm': 'SAMME.R',
#  'estimator': None,
#  'learning_rate': 1.0,
#  'n_estimators': 50,
#  'random_state': 4368}
